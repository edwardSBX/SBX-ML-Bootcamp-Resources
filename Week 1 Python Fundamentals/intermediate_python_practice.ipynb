# %% [markdown]
# # Intermediate Python Practice Notebook (Student Version)
#
# **macOS Optimized**
#
# **Setup Instructions**
#
# 1. Open Terminal in VS Code
# 2. Run:
#    ```bash
#    python3 -m venv venv
#    source venv/bin/activate
#    pip install pandas
#    ```
# 3. Select the `venv` kernel
#
# Complete every task listed under each question.

# %%
# === DEPENDENCY DEBUG CELL ===
import pandas as pd
print("✅ Pandas imported successfully!")

# %% [markdown]
# ## Question 1: Strings, Lists & List Comprehensions
#
# **Tasks** (complete all):
# 1. Strip whitespace from `text` and convert the entire string to lowercase.
# 2. Remove the characters `!` and `.`.
# 3. Split the cleaned text into a list of words.
# 4. Use a **list comprehension** to create a new list containing only words that have **4 or more letters**.
# 5. Use another list comprehension to reverse every word in the list from step 4.
# 6. Convert the reversed words list into a **set** to get unique values.
# 7. Print all intermediate results and the final count of unique reversed words.

# %%
# Question 1 - Your Code Here
text = "  The quick brown fox jumps over the lazy dog! Python is awesome for data science in 2024.  "
# TODO: Complete all 7 tasks above

# %% [markdown]
# ## Question 2: Dictionaries (Aggregation & Grouping)
#
# Given: `scores = [('Alice', 85), ('Bob', 92), ('Charlie', 78), ('Alice', 95), ('Bob', 88)]`
#
# **Tasks**:
# 1. Create a dictionary with each person’s **average score** (rounded to 1 decimal place).
# 2. Find and print the person with the **highest average**.
# 3. Create a new dictionary that groups people by their average score (score → list of names).
# 4. Create a set of all unique average scores.

# %%
# Question 2 - Your Code Here
scores = [('Alice', 85), ('Bob', 92), ('Charlie', 78), ('Alice', 95), ('Bob', 88)]
# TODO

# %% [markdown]
# ## Question 3: Sets
#
# Given two lists above.
#
# **Tasks**:
# 1. Convert both lists to sets.
# 2. Compute and print: intersection, union, difference (only in list1), symmetric difference.
# 3. Print the size (length) of each result.

# %%
# Question 3 - Your Code Here
list1 = ["python", "data", "ml", "ai", "python", "sql", "data"]
list2 = ["data", "sql", "tableau", "powerbi", "ai", "ml", "python"]
# TODO

# %% [markdown]
# ## Question 4: Functions + Conditionals + Loops
#
# **Write a function** `calculate_stats(numbers)` that takes a list of integers and returns a dictionary with exactly these keys:
# - `'positive_count'`, `'negative_count'`, `'zero_count'`
# - `'even_sum'`, `'odd_sum'`
# - `'max_value'`, `'min_value'`
#
# **Rules**: Use only loops and conditionals. Do **not** use `sum()`, `max()`, or `min()`.

# %%
# Question 4 - Your Code Here
def calculate_stats(numbers):
    # TODO
    pass

nums = [5, -3, 0, 8, -1, 4, 0, 12, -7, 3]
print(calculate_stats(nums))

# %% [markdown]
# ## Question 5: Debugging & Syntax
#
# Fix all bugs in the code below and improve it to also track how many times each fruit appears.

# %%
# Question 5 - Fix and Improve
data = ["apple:2", "banana:3", "apple:1", "cherry:5", "BANANA:2"]
# TODO: Fix and add count tracking

# %% [markdown]
# ## Question 6: Pandas Basics
#
# **Tasks**:
# 1. Create a DataFrame from the `products` list.
# 2. Filter rows where `stock > 20`.
# 3. Add a column `total_value` = price × stock.
# 4. Show summary statistics (`describe()`).
# 5. Sort the DataFrame by `total_value` descending.

# %%
# Question 6 - Your Code Here
import pandas as pd
products = [ ... ]  # paste the list
# TODO

# %% [markdown]
# ## Question 7: Pandas Data Cleaning
#
# **Tasks**:
# 1. Strip whitespace and convert names to Title Case.
# 2. Convert age to numeric (handle strings and missing values).
# 3. Fill missing cities with “Unknown” and title case them.
# 4. Remove duplicate names.
# 5. Print the cleaned DataFrame and `.info()`.

# %%
# Question 7 - Your Code Here
import pandas as pd
# TODO: Create dirty_data and clean it

# %% [markdown]
# ## Question 8: GroupBy & Aggregation
#
# **Tasks**:
# 1. Group by `region` and `category`.
# 2. Calculate: total_sales, avg_quantity, transaction count, total_quantity.
# 3. Add a column `sales_per_unit` = total_sales / total_quantity.
# 4. Reset index and print the final table.

# %%
# Question 8 - Your Code Here
import pandas as pd
# TODO

# %% [markdown]
# ## Question 9: Merge + Feature Engineering
#
# **Tasks**:
# 1. Perform a left merge of customers and orders on `customer_id`.
# 2. Create a boolean column `high_value` (True if amount > 200).
# 3. Group by `city` and calculate total_amount and high_value_count.
# 4. Print both the merged table and the city summary.

# %%
# Question 9 - Your Code Here
import pandas as pd
# TODO: create both DataFrames and complete tasks

# %% [markdown]
# ## Question 10: The Ultimate Challenge (Very Hard)
#
# **Tasks** (most people cannot finish this):
# 1. Write a function `parse_log(log)` that safely parses each string into a dictionary.
# 2. Handle missing fields, bad timestamps, and bad amounts using try/except.
# 3. Convert timestamp to datetime and amount to float when possible.
# 4. Build a clean pandas DataFrame.
# 5. Add `is_purchase` column.
# 6. Produce a summary dictionary with: unique users, total revenue, top user by revenue, most common action, error count.

# %%
# Question 10 - The Final Boss
import pandas as pd
logs = [ ... ]
# TODO: Full solution
