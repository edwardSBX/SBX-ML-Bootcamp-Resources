# %% [markdown]
# # Home Credit Default Risk - Pandas Practice
# **ML Bootcamp Week 2: SQL Fundamentals**
#
# Solve each question **using pandas** and **using SQL**. Note that the SQL queries must be run in your pgAdmin Query Editor. Use this notebook only for the pandas component.
# Compare your SQL results with your pandas results to ensure your outputs match.

# %%
#Setup Script. Modify db name.

import pandas as pd
from sqlalchemy import create_engine

db_name = '' # Update with your db name defined in your Docker Compose file
engine = create_engine(f"postgresql://bootcamp:bootcamp123@localhost:5432/{db_name}")


#Details should match upload script
print("Loading data...")
app = pd.read_sql("SELECT * FROM application_train", engine)
prev = pd.read_sql("SELECT * FROM previous_application", engine)
bureau = pd.read_sql("SELECT * FROM bureau", engine)
inst = pd.read_sql("SELECT * FROM installments_payments LIMIT 100000", engine)

print(f"✅ Loaded {len(app):,} applications, {len(prev):,} previous apps, {len(bureau):,} bureau records, and {len(inst):,} installment records")
# Out:
# Loading data...
# ✅ Loaded 8,000 applications, 36,927 previous apps, 37,559 bureau records, and 15,653 installment records

# %% [markdown]
# ### Q1: Default Rate & Average Credit Analysis by Customer Segment
#
# **Business Context**:
# As a credit risk analyst at Home Credit, you want to understand which customer groups are more likely to default on their loans. This analysis helps the bank identify high-risk segments early and adjust lending strategies accordingly.
#
# **Task**:
# Calculate the following for each combination of gender and income type:
# - Total number of loan applicants
# - Default Rate (%) — what percentage of these customers defaulted (`TARGET = 1`)
# - Average credit amount requested
#
# **Requirements**:
# - Group by `CODE_GENDER` and `NAME_INCOME_TYPE`
# - Sort by Default Rate (highest risk first)
# - Round Default Rate to 2 decimals and Average Credit to 0 decimals

# %% [markdown]
# ### Q2: Previous Application Approval Rate by Gender
# **Task**: For each gender, calculate:
# - Number of unique customers who had previous applications
# - The percentage of those previous applications that were **Approved**

# %% [markdown]
# ### Q3: Top 5 Highest Previous Credit Customers per Gender (Window Function Style)
# **Task**: For each gender, find the **top 5 customers** who have the highest total credit amount from previous applications.

# %% [markdown]
# ### Q4: High-Risk Customers with Payment Delays
# **Task**: Find customers who:
# 1. Have **high credit amount** (above 75th percentile), **AND**
# 2. Have **significant payment delays** (average > 30 days late on installments)
#
# Show default rate and average days late by gender.

# %% [markdown]
# ### Q5: Credit Instability Score
# **Task**: Create a composite **“Instability Score”** for customers who defaulted (`TARGET = 1`) using the following features:
# - `active_last_2y`: Number of active bureau credits in last 2 years
# - `total_prolongations`: How many times they prolonged credits
# - `avg_payment_delay`: Average days late on installments
#
# Score = `(active_last_2y × 2) + (total_prolongations × 5) + (avg_delay × 3)`
#
# Show the **top 10 most unstable defaulters**.
